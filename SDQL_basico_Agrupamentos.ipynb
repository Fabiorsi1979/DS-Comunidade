# %% [markdown]
# <a href="https://colab.research.google.com/github/Fabiorsi1979/DS-Comunidade/blob/main/SDQL_basico_Agrupamentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Perguntas do CEO

# %% [markdown]
# ## Funções de Agrupamento - SQL com Phyton
#
# #####  - As funções de agrupamentos unificam categorias para que seja possível funções agregadoras e insights
# #####  - Utiliza-se a clausula GROUP BY para indicar as colunas que estão sendo agrupadas

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import sqlite3

# %%
path = ("/content/drive/MyDrive/db_olist.sqlite")

# %%
def sql_agrup (*args):
    conexao = sqlite3.connect(path)
    cursor = conexao.cursor()

    cursor.execute(consulta)
    dados = cursor.fetchall()

    cursor.close
    conexao.close

    consulta_sql = pd.DataFrame(dados, columns=[colunas])
    return consulta_sql

# %% [markdown]
# #### 1. Qual o número de clientes únicos de todos os estados?

# %%
consulta = "SELECT c.customer_state, COUNT (DISTINCT c.customer_id) FROM customer c GROUP BY c.customer_state"
colunas = ["UF","Quant_clientes"]

exercicio1 = sql_agrup(consulta,colunas)
exercicio1
# Out:
#     UF Quant_clientes
# 0   AC             81
# 1   AL            413
# 2   AM            148
# 3   AP             68
# 4   BA           3380
# 5   CE           1336
# 6   DF           2140
# 7   ES           2033
# 8   GO           2020
# 9   MA            747
# 10  MG          11635
# 11  MS            715
# 12  MT            907
# 13  PA            975
# 14  PB            536
# 15  PE           1652
# 16  PI            495
# 17  PR           5045
# 18  RJ          12852
# 19  RN            485
# 20  RO            253
# 21  RR             46
# 22  RS           5466
# 23  SC           3637
# 24  SE            350
# 25  SP          41746
# 26  TO            280

# %% [markdown]
# #### 2. Qual o número de cidades únicas de todos os estados?

# %%
consulta = "SELECT geo.geolocation_state, COUNT (DISTINCT geo.geolocation_city) FROM geolocation geo GROUP BY geo.geolocation_state"
colunas =  ["UF","Qtd_cidades"]

exercicio2 = sql_agrup(consulta,colunas)
exercicio2
# Out:
#     UF Qtd_cidades
# 0   AC          34
# 1   AL         130
# 2   AM          74
# 3   AP          17
# 4   BA         652
# 5   CE         260
# 6   DF          28
# 7   ES         160
# 8   GO         384
# 9   MA         299
# 10  MG        1426
# 11  MS         133
# 12  MT         213
# 13  PA         219
# 14  PB         254
# 15  PE         267
# 16  PI         278
# 17  PR         651
# 18  RJ         245
# 19  RN         214
# 20  RO          83
# 21  RR          14
# 22  RS         691
# 23  SC         420
# 24  SE          96
# 25  SP        1048
# 26  TO         173

# %% [markdown]
# #### 3. Qual o número de clientes únicos por estado e por cidade?

# %%
consulta = "SELECT c.customer_state, c.customer_city, COUNT(DISTINCT c.customer_id)FROM customer c GROUP BY c.customer_state, c.customer_city"
colunas =  ["UF","Cidades","Qtd_clientes"]

exercicio3 = sql_agrup(consulta,colunas)
exercicio3
# Out:
#       UF                  Cidades Qtd_clientes
# 0     AC                brasileia            1
# 1     AC          cruzeiro do sul            3
# 2     AC           epitaciolandia            1
# 3     AC            manoel urbano            1
# 4     AC               porto acre            1
# ...   ..                      ...          ...
# 4305  TO             silvanopolis            1
# 4306  TO  sitio novo do tocantins            2
# 4307  TO               taguatinga            3
# 4308  TO           tocantinopolis            7
# 4309  TO                  xambioa            3
#
# [4310 rows x 3 columns]

# %% [markdown]
# #### 4. Qual a maior venda por vendedor?

# %%
consulta = "SELECT oi.seller_id, SUM(oi.price) FROM order_items oi GROUP BY oi.seller_id"
colunas =  ["Codigo_Vendedor","Maior_Venda"]

exercicio4 = sql_agrup(consulta,colunas)
exercicio4
# Out:
#                        Codigo_Vendedor Maior_Venda
# 0     0015a82c2db000af6aaaf3ae2ecb0532     2685.00
# 1     001cca7ae9ae17fb1caed9dfb1094831    25080.03
# 2     001e6ad469a905060d959994f1b41e4f      250.00
# 3     002100f778ceb8431b7a1020ff7ab48f     1234.50
# 4     003554e2dce176b5555353e4f3555ac8      120.00
# ...                                ...         ...
# 3090  ffcfefa19b08742c5d315f2791395ee5       69.90
# 3091  ffdd9f82b9a447f6f8d4b91554cc7dd3     2101.20
# 3092  ffeee66ac5d5a62fe688b9d26f83f534     1839.86
# 3093  fffd5413c0700ac820c7069d66d98c89     9062.30
# 3094  ffff564a4f9085cd26170f4732393726     1426.30
#
# [3095 rows x 2 columns]

# %% [markdown]
# #### 5. Qual o número total de pedidos únicos por cada vendedor?

# %%
consulta = "SELECT oi.seller_id, COUNT (DISTINCT oi.order_id) FROM order_items oi GROUP BY oi.seller_id"
colunas =  ["Vendedor","Total_pedidos"]

exercicio5 = sql_agrup(consulta,colunas)
exercicio5
# Out:
#                               Vendedor Total_pedidos
# 0     0015a82c2db000af6aaaf3ae2ecb0532             3
# 1     001cca7ae9ae17fb1caed9dfb1094831           200
# 2     001e6ad469a905060d959994f1b41e4f             1
# 3     002100f778ceb8431b7a1020ff7ab48f            51
# 4     003554e2dce176b5555353e4f3555ac8             1
# ...                                ...           ...
# 3090  ffcfefa19b08742c5d315f2791395ee5             1
# 3091  ffdd9f82b9a447f6f8d4b91554cc7dd3            18
# 3092  ffeee66ac5d5a62fe688b9d26f83f534            14
# 3093  fffd5413c0700ac820c7069d66d98c89            60
# 3094  ffff564a4f9085cd26170f4732393726            20
#
# [3095 rows x 2 columns]

# %% [markdown]
# #### 6. Qual o número total de pedidos únicos, a data mínima e máxima de limite envio, o valor máximo, mínimo e médio do frete dos pedidos por cada vendedor?

# %%
consulta = "SELECT oi.seller_id AS vendedor, COUNT (DISTINCT oi.order_id) AS Total_Pedidos, MAX (oi.shipping_limit_date) AS envio_mais_Antigo, MIN (oi.shipping_limit_date) AS envio_mais_Proximo, MAX (oi.freight_value) AS Maior_valor_Frete, MIN(oi.freight_value) AS Menor_valor_frete, AVG(oi.freight_value) AS Frete_medio FROM order_items oi GROUP BY oi.seller_id"
colunas =  ["Vendedor","Total_pedidos","Maior_data_envio","Menor_data_envio"," Maior_frete","Menor_frete","Frete_medio"]

exercicio6 = sql_agrup(consulta,colunas)
exercicio6
# Out:
#                               Vendedor Total_pedidos     Maior_data_envio  \
# 0     0015a82c2db000af6aaaf3ae2ecb0532             3  2017-10-24 23:56:20
# 1     001cca7ae9ae17fb1caed9dfb1094831           200  2018-07-19 21:50:17
# 2     001e6ad469a905060d959994f1b41e4f             1  2018-08-13 23:05:23
# 3     002100f778ceb8431b7a1020ff7ab48f            51  2018-04-18 13:11:45
# 4     003554e2dce176b5555353e4f3555ac8             1  2017-12-21 07:11:03
# ...                                ...           ...                  ...
# 3090  ffcfefa19b08742c5d315f2791395ee5             1  2018-06-28 17:55:45
# 3091  ffdd9f82b9a447f6f8d4b91554cc7dd3            18  2018-08-29 12:10:52
# 3092  ffeee66ac5d5a62fe688b9d26f83f534            14  2018-05-22 03:30:31
# 3093  fffd5413c0700ac820c7069d66d98c89            60  2018-08-28 20:10:15
# 3094  ffff564a4f9085cd26170f4732393726            20  2017-04-19 02:45:41
#
#          Menor_data_envio  Maior_frete Menor_frete Frete_medio
# ...

# %% [markdown]
# #### 7. Qual o valor médio, máximo e mínimo do preço de todos os pedidos de cada produto?

# %%
consulta = "SELECT oi.product_id, AVG(oi.price), MAX (oi.price), MIN (oi.price) FROM order_items oi GROUP BY oi.product_id "
colunas =  ['Produto','Media_preço_prod','Maior_valor_produto','Menor_valor_produto']

exercicio7 = sql_agrup(consulta,colunas)
exercicio7
# Out:
#                                 Produto Media_preço_prod Maior_valor_produto  \
# 0      00066f42aeeb9f3007548bb9d3f33c38           101.65              101.65
# 1      00088930e925c41fd95ebfe695fd2655           129.90              129.90
# 2      0009406fd7479715e4bef61dd91f2462           229.00              229.00
# 3      000b8f95fcb9e0096488278317764d19            58.90               58.90
# 4      000d9be29b5207b54e86aa1b1ac54872           199.00              199.00
# ...                                 ...              ...                 ...
# 32946  fff6177642830a9a94a0f2cba5e476d1           114.99              119.99
# 32947  fff81cc3158d2725c0655ab9ba0f712c            90.00               90.00
# 32948  fff9553ac224cec9d15d49f5a263411f            32.00               32.00
# 32949  fffdb2d0ec8d6a61f0a0a0db3f25b441            33.99               34.99
# 32950  fffe9eeff12fcbd74a2f2b007dde0c58           249.99              249.99
#
#       Menor_valor_produto
# ...

# %% [markdown]
# #### 8. Qual a quantidade de vendedores distintos que receberam algum pedido e o preço médio das vendas?

# %%
consulta = "SELECT COUNT(DISTINCT oi.seller_id), AVG(oi.price)  FROM order_items oi GROUP BY oi.seller_id"
colunas =  ["Vendedores", "Media_Vendas"]

exercicio8 = sql_agrup(consulta,colunas)
exercicio8
# Out:
#      Vendedores Media_Vendas
# 0             1   895.000000
# 1             1   104.937364
# 2             1   250.000000
# 3             1    22.445455
# 4             1   120.000000
# ...         ...          ...
# 3090          1    69.900000
# 3091          1   105.060000
# 3092          1   131.418571
# 3093          1   148.562295
# 3094          1    71.315000
#
# [3095 rows x 2 columns]

# %% [markdown]
# #### 9. Qual a quantidade de pedidos por tipo de pagamentos?

# %%
consulta = "SELECT op.payment_type,COUNT (op.order_id) FROM order_payments op GROUP BY op.payment_type"
colunas =  ["Tipo_Pagamento","Qtd_pedidos"]

exercicio9 = sql_agrup(consulta,colunas)
exercicio9
# Out:
#   Tipo_Pagamento Qtd_pedidos
# 0         boleto       19784
# 1    credit_card       76795
# 2     debit_card        1529
# 3    not_defined           3
# 4        voucher        5775

# %% [markdown]
# #### 10. Qual a quantidade de pedidos, a média do valor do pagamento e o número máximo de parcelas por tipo de pagamentos?

# %%
consulta = "SELECT op.payment_type, COUNT(op.order_id), AVG(op.payment_value), MAX(op.payment_sequential) FROM order_payments op GROUP BY op.payment_type"
colunas =  ["Tipo_pag","Total_Pedidos","Media_pag","Maior_num_parcelas"]

exercicio10 = sql_agrup(consulta,colunas)
exercicio10
# Out:
#       Tipo_pag Total_Pedidos   Media_pag Maior_num_parcelas
# 0       boleto         19784  145.034435                  2
# 1  credit_card         76795  163.319021                  3
# 2   debit_card          1529  142.570170                  3
# 3  not_defined             3    0.000000                  1
# 4      voucher          5775   65.703354                 29

# %% [markdown]
# #### 11. Qual a valor mínimo, máximo, médio e as soma total paga por cada tipo de pagamento e número de parcelas disponíveis?

# %%
consulta = "SELECT op.payment_type,op.payment_installments,MIN(op.payment_value),MAX(op.payment_value),AVG(op.payment_value),SUM(op.payment_value) FROM order_payments op GROUP BY op.payment_type, op.payment_installments"
colunas =  ["Tipo_pag","Num_parc","Menor_valor","Maior_valor","Media","Total"]

exercicio11 = sql_agrup(consulta,colunas)
exercicio11
# Out:
#        Tipo_pag Num_parc Menor_valor Maior_valor       Media       Total
# 0        boleto        1       11.62     7274.88  145.034435  2869361.27
# 1   credit_card        0       58.69      129.94   94.315000      188.63
# 2   credit_card        1        0.01    13664.08   95.872930  2440445.43
# 3   credit_card        2       20.03     2442.82  127.228150  1579283.03
# 4   credit_card        3       30.00     3256.14  142.539317  1491103.80
# 5   credit_card        4       40.00     3126.50  163.976840  1163907.61
# 6   credit_card        5       49.99     4809.44  183.465222   961174.30
# 7   credit_card        6       59.99     2828.42  209.849952   822611.81
# 8   credit_card        7       69.97     2094.44  187.673672   305157.39
# 9   credit_card        8       37.58     6929.31  307.737427  1313423.34
# 10  credit_card        9       90.11     2116.01  203.440870   131015.92
# 11  credit_card       10       37.67     4950.34  415.085837  2211577.34
# ...

# %% [markdown]
# #### 12. Qual a média de pedidos por cliente?

# %%
consulta = "SELECT o.customer_id, AVG(o.order_id) FROM orders o GROUP BY o.customer_id"
colunas =  ["Clientes","Media_pedidos"]

exercicio12 = sql_agrup(consulta,colunas)
exercicio12
# Out:
#                                Clientes Media_pedidos
# 0      00012a2ce6f8dcda20d059ce98491703           5.0
# 1      000161a058600d5901f007fab4c27140           0.0
# 2      0001fd6190edaaf884bcaf3d49edf079         316.0
# 3      0002414f95344307404f0ace7a26f1d5        5825.0
# 4      000379cdec625522490c315e70c7a9fb           0.0
# ...                                 ...           ...
# 99436  fffecc9f79fd8c764f843e9951b11341         814.0
# 99437  fffeda5b6d849fbd39689bb92087f431           8.0
# 99438  ffff42319e9b2d713724ae527742af25          83.0
# 99439  ffffa3172527f765de70084a7e53aae8           0.0
# 99440  ffffe8b65bbe3087b653a978c870db99           inf
#
# [99441 rows x 2 columns]

# %% [markdown]
# #### 13. Qual a quantidade de pedidos por status?

# %%
consulta = "SELECT o.order_status, COUNT (DISTINCT o.order_id) FROM orders o GROUP BY o.order_status"
colunas =  ["Status","Qtde_pedidos"]

exercicio13 = sql_agrup(consulta,colunas)
exercicio13
# Out:
#         Status Qtde_pedidos
# 0     approved            2
# 1     canceled          625
# 2      created            5
# 3    delivered        96478
# 4     invoiced          314
# 5   processing          301
# 6      shipped         1107
# 7  unavailable          609

# %% [markdown]
# #### 14. Qual a quantidade de pedidos realizados por dia?
# **OBS: Use o comando DATE( ) para converter de timestamp (data com hora) para apenas data!**

# %%
consulta = "SELECT DATE(order_purchase_timestamp), COUNT(o.order_id) FROM orders o GROUP BY DATE(o.order_purchase_timestamp)"
colunas =  ["Dia","Qtde_pedidos"]

exercicio14 = sql_agrup(consulta,colunas)
exercicio14
# Out:
#             Dia Qtde_pedidos
# 0    2016-09-04            1
# 1    2016-09-05            1
# 2    2016-09-13            1
# 3    2016-09-15            1
# 4    2016-10-02            1
# ..          ...          ...
# 629  2018-09-29            1
# 630  2018-10-01            1
# 631  2018-10-03            1
# 632  2018-10-16            1
# 633  2018-10-17            1
#
# [634 rows x 2 columns]

# %% [markdown]
# #### 15. Quantos produtos estão cadastrados na empresa por categoria?

# %%
consulta = "SELECT p.product_category_name, COUNT(p.product_id) FROM products p GROUP BY p.product_category_name"
colunas =  ["Categorias","Prod_Cadastrados"]

exercicio15 = sql_agrup(consulta,colunas)
exercicio15
# Out:
#                    Categorias Prod_Cadastrados
# 0                        None              610
# 1   agro_industria_e_comercio               74
# 2                   alimentos               82
# 3           alimentos_bebidas              104
# 4                       artes               55
# ..                        ...              ...
# 69    sinalizacao_e_seguranca               93
# 70   tablets_impressao_imagem                9
# 71                  telefonia             1134
# 72             telefonia_fixa              116
# 73      utilidades_domesticas             2335
#
# [74 rows x 2 columns]

# %% [markdown]
# ### 16. Qual a quantidade de pedidos realizado por cada status do pedido, a partir do dia 23 de setembro de 2016?

# %%
consulta = "SELECT o.order_status, COUNT(o.order_id) FROM orders o WHERE DATE(o.order_purchase_timestamp)>= '2016-09-23' GROUP BY o.order_status"
colunas =  ["Status","Qtde_Pedidos"]

exercicio16 = sql_agrup(consulta,colunas)
exercicio16
# Out:
#         Status Qtde_Pedidos
# 0     approved            2
# 1     canceled          623
# 2      created            5
# 3    delivered        96477
# 4     invoiced          314
# 5   processing          301
# 6      shipped         1106
# 7  unavailable          609

# %% [markdown]
# #### 17. Qual a quantidade de pedidos realizados por dia a partir do dia 23 de setembro de 2024

# %%
consulta = "SELECT DATE(o.order_purchase_timestamp), COUNT(o.order_id)  FROM orders o WHERE DATE(o.order_purchase_timestamp)>='2024-09-23' GROUP BY DATE(o.order_purchase_timestamp)"
colunas =  ["Datas","Qdte_pedidos"]

exercicio17 = sql_agrup(consulta,colunas)
exercicio17
# Out:
# Empty DataFrame
# Columns: [(Datas,), (Qdte_pedidos,)]
# Index: []
